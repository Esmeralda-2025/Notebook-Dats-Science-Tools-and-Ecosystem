# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## In this notebook, Data Science Tools and Ecosystem are summarized

# %% [markdown]
# ### **Objectives:**
#       - List popular programming languages used in Data Science in 2025
#       - Identify and order the most commonly used libraries for Data Science
#       - Understand basic arithmetic operations in Python with code examples
#       - Learn about open-source development environments used in Data Science
#       - Summarize key takeaways of Data Science workflows and tools

# %% [markdown]
# ### Here are the most used languages by data scientists by popularity and order in 2025:
#     1.  Python (dominant in data science, AI und Machine Learning)
#     2.  R (strong for statistics and data visualization)
#     3.  SQL (Standard for DB queries)
#     4.  Java (often for big data and enterprise applications)
#     5.  Julia (rising for numerical calculation and analysis)
#     6.  Scala (especially for Apache Spark in data engineering)
#     7.  C/C++ (performant algorithms and numerical analysis)
#     8.  Go (fast growing in backend/data engineering)
#     9.  Rust (gaining importance for performant and secure applications)
#     10. JavaScript (for data-driven web applications and visualization)

# %% [markdown]
# ### 10 of the most commonly used libraries by Data Scientists, ordered by overall popularity and fundamental use:
#     1.  NumPy (numerical computation, arrays)
#     2.  Pandas (data manipulation and analysis)
#     3.  Matplotlib (basic data visualization and plotting)
#     4.  Seaborn (statistical data visualization, built on Matplotlib)
#     5.  Scikit-learn (machine learning algorithms and tools)
#     6.  SciPy (advanced mathematics, optimization, and statistics)
#     7.  TensorFlow (deep learning and neural networks)
#     8.  PyTorch (deep learning and neural networks)​
#     9.  Keras (user-friendly neural network API running on TensorFlow)
#     10. Plotly (interactive, web-based visualizations and dashboards)

# %% [markdown]
# | Data Science Tools  |
# |---------------------|
# | Jupyter Notebook    |
# | RStudio             |
# | Apache Spark        |

# %% [markdown]
# ### Blow are a few examples of evaluating arithmetic expressions in Python

# %%
#This is a simple arithmetric expression to multiply and then add integers
(3*4)+5
# Out:
# 17

# %%
#This operation will convert 200 minutes to hours by dividing by 60
round(200/60,2)
# Out:
# 3.33

# %% [markdown]
# ## Author
#    Asmaa B.
